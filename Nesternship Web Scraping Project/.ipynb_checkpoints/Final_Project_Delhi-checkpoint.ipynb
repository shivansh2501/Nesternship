# %%
from bs4 import BeautifulSoup
import lxml
import requests
import pandas as pd

# %%
html_text = requests.get('https://www.healthfrog.in/hospital/pet-clinics/delhi/delhi').text

print(html_text)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>List of Pet Clinics in Bangalore - healthFROG </title><link rel="SHORTCUT ICON" href="https://www.healthfrog.in/images/favicon.png"/><meta name="viewport" content="width=device-width, initial-scale=1" /><link href="https://www.healthfrog.in/theme/bootstrap/bootstrap.min.css" rel="stylesheet" /><link href="https://www.healthfrog.in/theme/fa/css/font-awesome.min.css" rel="stylesheet" /><link href="https://www.healthfrog.in/theme/style.css" rel="stylesheet" /><!-- Google tag (gtag.js) --><script async src="https://www.googletagmanager.com/gtag/js?id=G-K2Z8CKG6EX"></script><script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-K2Z8CKG6EX');</script></head><body> <div id="header"> <div class="container"> <div class="row"> <div class="col-lg-3 col-md-3 col-sm-12"> <div class="logo"> <a href="https://www.healthfrog.in/">healthFROG</a> </div> </div> <div class="col-lg-6 col-md-6 col-sm-12"> <div class="hc-wrap"> <form action="https://www.healthfrog.in/searchdirectory" name="search" id="search" method="post"> <div class="form-group"> <div class="input-group"> <input class="form-control" name="search" type="text" id="searchText" autocomplete="off" placeholder="Search..."/> <input id="searchVal" name="searchval" type="hidden"/> <span class="input-group-btn"> <button class="btn btn-default" accesskey="13" type="submit"><i class="fa fa-search"></i></button> </span> </div> </div> </form> </div> </div> <div class="col-lg-3 col-md-3 col-sm-12"> <div class="hc-wrap"> <a href="https://www.healthfrog.in/add-listing.html" class="btn bt-style3 dis-bl"><i class="fa fa-plus-circle"></i>Add Your Hospital</a> </div> </div> </div> </div></div><div id="navigation"> <div class="container"> <div class="row"> <div class="col-lg-12 col-md-12 col-sm-12"> <nav class="navbar navbar-default"> <div class="container-fluid"> <div class="navbar-header"> <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1"> <span class="sr-only"><i class="fa fa-home"></i></span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span> </button> </div> <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1"> <ul class="nav navbar-nav"> <li><a href="https://www.healthfrog.in/hospital">Hospital</a></li> <li><a href="https://www.healthfrog.in/chemists">Chemists</a></li> <li><a href="https://www.healthfrog.in/doctor">Doctor</a></li> <li><a href="https://www.healthfrog.in/laboratory">Laboratory</a></li> <li><a href="https://www.healthfrog.in/health-and-fitness">Health & Fitness</a></li> </ul><ul class="nav navbar-nav navbar-right"><li><a href="javascript:void(0)">About Us</a></li><li><a href="https://www.healthfrog.in/contact-us.html">Contact Us</a></li> <li><a href="https://www.healthfrog.in/policy.html">Policy</a></li> <li><a href="https://www.healthfrog.in/signup.html">Signup</a></li><li><a href="https://www.healthfrog.in/login.html">Login</a></li> </ul> </div> </div> </nav> </div> </div> </div></div><div id="sel-nav"> <div class="container"> <div class="row"> <div class="col-lg-3 col-md-3 col-sm-6"> <div class="form-group"> <form id="catform" action=""> <select class="form-control" id="catlist" onchange="changeUrl('cat',this.options[this.selectedIndex].value)"> <option value="">Select Category</option> <option selected="selected" value="hospital"> Hospital</option> <option value="chemists"> Chemists</option> <option value="doctor"> Doctor</option> <option value="laboratory"> Laboratory</option> <option value="health-and-fitness"> Health & Fitness</option> </select> </form> </div> </div> <div class="col-lg-3 col-md-3 col-sm-6"> <div class="form-group"> <form id="typeform" action="" > <select class="form-control" id="typelist" onchange="changeUrl('type',this.options[this.selectedIndex].value)"> <option value="list">All Lis ...
# $(document).ready(function(){	$('#searchText').typeahead({	source: function (query, process) {	$('#searchText').addClass("lodn");	$.ajax({	url: 'https://www.healthfrog.in/search',	type: 'GET',	dataType: 'JSON',	data: 'q=' + query,	success: function(data) {	$('#searchText').removeClass("lodn");	process(data);	}	});	},	updater : function(item){	var nm=item.split(',',1);	$('#searchVal').val(item);	var nnm=nm[0];	nnm = nnm.replace(' <span class="searchAJ-id">','');	this.$element[0].value = nnm;	this.$element[0].form.submit();	return nnm;	} });
# });
# })(jQuery);
# function changeUrl(action,value)
# {	if(action=="cat")	{	location.href="https://www.healthfrog.in/"+value;	}	else if(action=="type")	{	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+value;	}	else if(action=="state")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+value;	}	else if(action=="city")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	var state = document.getElementById("statelist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+state+'/'+value;	}
# }
# function showMoreRecord(page,mcatid,keyword,state,city,divId)
# {	var seurl = "page="+page+"&mcatid="+mcatid+"&keyword="+keyword+"&state="+state+"&city="+city;	var xmlhttp;	if (window.XMLHttpRequest)	{	xmlhttp=new XMLHttpRequest();	}	else	{	xmlhttp=new ActiveXObject("Microsoft.XMLHTTP");	};	xmlhttp.onreadystatechange=function()	{	if (xmlhttp.readyState==4 && xmlhttp.status==200)	{	page = +page + 1;	if(xmlhttp.responseText.trim()=="")	{	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'none';	}	else	{	document.getElementById(divId).innerHTML=document.getElementById(divId).innerHTML + xmlhttp.responseText;	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'block';	}	document.getElementById("loadmore").setAttribute("onClick","javascript:showMoreRecord("+page+",'"+mcatid+"','"+keyword+"','"+state+"','"+city+"','"+divId+"');");	}	else	{	document.getElementById('loadmsg').style.display = 'block';	document.getElementById('pagination').style.display = 'none';	};	};	xmlhttp.open("POST","https://www.healthfrog.in/importlisting.html",true);	xmlhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");	xmlhttp.send(seurl);
# }</script><script language="javascript" type="application/javascript">jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/state.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+19,	success: function(data) {	$('#statelist').append(data);	}, error: function(ajaxobj){ $('#statelist').append(ajaxobj.responseText); }	});	});	})(jQuery);</script><script language="javascript" type="application/javascript">jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/city.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+19+'&ctid='+324,	success: function(data) {	$('#citylist').append(data);	}, error: function(ajaxobj){ $('#citylist').append(ajaxobj.responseText); }	});	});	})(jQuery);</script> </body></html>

# %%
soup = BeautifulSoup(html_text, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Pet Clinics in Bangalore - healthFROG
#   </title>
#   <link href="https://www.healthfrog.in/images/favicon.png" rel="SHORTCUT ICON"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.healthfrog.in/theme/bootstrap/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://www.healthfrog.in/theme/fa/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="https://www.healthfrog.in/theme/style.css" rel="stylesheet"/>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-K2Z8CKG6EX">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-K2Z8CKG6EX');
#   </script>
#  </head>
#  <body>
#   <div id="header">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-12">
#       <div class="logo">
#        <a href="https://www.healthfrog.in/">
#         healthFROG
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-6 col-md-6 col-sm-12">
#       <div class="hc-wrap">
#        <form action="https://www.healthfrog.in/searchdirectory" id="search" method="post" name="search">
#         <div class="form-group">
#          <div class="input-group">
#           <input autocomplete="off" class="form-control" id="searchText" name="search" placeholder="Search..." type="text"/>
#           <input id="searchVal" name="searchval" type="hidden"/>
#           <span class="input-group-btn">
#            <button accesskey="13" class="btn btn-default" type="submit">
#             <i class="fa fa-search">
#             </i>
#            </button>
#           </span>
#          </div>
#         </div>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-12">
#       <div class="hc-wrap">
#        <a class="btn bt-style3 dis-bl" href="https://www.healthfrog.in/add-listing.html">
#         <i class="fa fa-plus-circle">
#         </i>
#         Add Your Hospital
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="navigation">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-12 col-md-12 col-sm-12">
#       <nav class="navbar navbar-default">
#        <div class="container-fluid">
#         <div class="navbar-header">
#          <button class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#           <span class="sr-only">
#            <i class="fa fa-home">
#            </i>
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#          <ul class="nav navbar-nav">
#           <li>
#            <a href="https://www.healthfrog.in/hospital">
#             Hospital
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/chemists">
#             Chemists
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/doctor">
#             Doctor
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/laboratory">
#             Laboratory
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/health-and-fitness">
#             Health &amp; Fitness
#            </a>
#           </li>
#          </ul>
#          <ul class="nav navbar-nav navbar-right">
#           <li>
#            <a href="javascript:void(0)">
#             About Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/contact-us.html">
#             Contact Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/policy.html">
#             Policy
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/signup.html">
#             Signup
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/login.html">
#             Login
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="sel-nav">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="catform">
#         <select class="form-control" id="catlist" onchange="changeUrl('cat',this.options[this.selectedIndex].value)">
#          <option value="">
#           Select Category
#          </option>
#          <option selected="selected" value="hospital">
#           Hospital
#          </option>
#          <option value="chemists">
#           Chemists
#          </option>
#          <option value="doctor">
#           Doctor
#          </option>
#          <option value="laboratory">
#           Laboratory
#          </option>
#          <option value="health-and-fitness">
#           Health &amp; Fitness
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="typeform">
#         <select class="form-control" id="typelist" onchange="changeUrl('type',this.options[this.selectedIndex].value)">
#          <option value="list">
#           All List
#          </option>
#          <option value="anesthesiology-hospital">
#           Anesthesiology Hospital
#          </option>
#          <option value="ayurvedic-hospital">
#           Ayurvedic Hospital
#          </option>
#          <option value="cancer-hospital">
#           Cancer Hospital
#          </option>
#          <option value="cardiology-hospital">
#           Cardiology Hospital
#          </option>
#          <option value="children-hospital">
#           Children Hospital
#          </option>
#          <option value="cosmetic-and-plastic-surgery-hospital">
#           Cosmetic &amp; Plastic Surgery Hospital
#          </option>
#          <option value="dental-hospital">
#           Dental Hospital
#          </option>
#          <option value="dermatology-hospital">
#           Dermatology Hospital
#          </option>
#          <option value="ent-hospital">
#           ENT Hospital
#          </option>
#          <option value="gastroenterologist-hospital">
#           Gastroenterologist Hospital
#          </option>
#          <option value="general-hospital">
#           General Hospital
#          </option>
#          <option value="gynecology-hospital">
#           Gynecology Hospital
#          </option>
#          <option value="homeopathy-hospital">
#           Homeopathy Hospital
#          </option>
#          <option value="neurology-hospital">
#           Neurology Hospital
#          </option>
#          <option value="oncology-hospital">
#           Oncology Hospital
#          </option>
#          <option value="orthopaedic-hospital">
#           Orthopaedic Hospital
#          </option>
#          <option value="private-hospital">
#           Private Hospital
#          </option>
#          <option value="psychiatric-hospital">
#           Psychiatric Hospital
#          </option>
#          <option value="radiology-hospital">
#           Radiology Hospital
#          </option>
#          <option value="diabetes-hospital">
#           Diabetes Hospital
#          </option>
#          <option value="emergency-hospital">
#           Emergency Hospital
#          </option>
#          <option value="maternity-hospital">
#           Maternity Hospital
#          </option>
#          <option value="urology-hospital">
#           Urology Hospital
#          </option>
#          <option value="nephrology-hospital">
#           Nephrology Hospital
#          </option>
#          <option value="opthalmology-hospital">
#           Opthalmology Hospital
#          </option>
#          <option value="eye-hospital">
#           Eye Hospital
#          </option>
#          <option value="rheumatology-hospital">
#           Rheumatology Hospital
#          </option>
#          <option value="hematology-hospital">
#           Hematology Hospital
#          </option>
#          <option value="immunology-hospital">
#           Immunology Hospital
#          </option>
#          <option value="mental-hospital">
#           Mental Hospital
#          </option>
#          <option value="public-hospital">
#           Public Hospital
#          </option>
#          <option value="government-hospital">
#           Government Hospital
#          </option>
#          <option value="veterinary-hospital">
#           Veterinary Hospital
#          </option>
#          <option value="multispeciality-hospital">
#           Multispeciality Hospital
#          </option>
#          <option value="cardiac-hospital">
#           Cardiac Hospital
#          </option>
#          <option value="charitable-hospital">
#           Charitable Hospital
#          </option>
#          <option value="esis-hospital">
#           Esis Hospital
#          </option>
#          <option selected="selected" value="pet-clinics">
#           Pet Clinics
#          </option>
#          <option value="public-veterinary-hospital">
#           Public Veterinary Hospital
#          </option>
#          <option value="orthodontic-hospitals">
#           Orthodontic Hospitals
#          </option>
#          <option value="dental-implants-center">
#           Dental Implants Center
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="stateform">
#         <select class="form-control" id="statelist" onchange="changeUrl('state',this.options[this.selectedIndex].value)">
#          <option value="">
#           Select State
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="cityform">
#         <select class="form-control" id="citylist" onchange="changeUrl('city',this.options[this.selectedIndex].value)">
#          <option value="">
#           Select City
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="body">
#    <div class="container">
#     <div class="row">
#      <div align="center" class="m1">
#       <script id="mNCC" language="javascript">
#        medianet_width = "970"; medianet_height = "90"; medianet_crid = "834543454"; medianet_versionId = "3111299";
#       </script>
#       <script src="//contextual.media.net/nmedianet.js?cid=8CU5P8N3J">
#       </script>
#      </div>
#      <div class="col-lg-8 col-md-8 col-sm-12">
#       <div class="lising-wrap">
#        <div class="title">
#         <h1>
#          <i class="fa fa-th-list">
#          </i>
#          List of Pet Clinics in Bangalore
#         </h1>
#        </div>
#        <div class="post p0" id="setrecord">
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/tyre-care-centre-tyre-clinic-bangalore-rew3cqoo@.html">
#            Tyre Care Centre +tyre Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           1y, 100 Ft Ring Road, , D Souza Layout, , Ashoknagar, , Bangalore, Karnataka - 560025,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/om-shivas-tyre-clinic-bangalore-k3ee2_8p4.html">
#            Om Shiva's Tyre Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           65, Nagarabhavi Main Rd, , Govindarajanagar, Vijayanagar, , Bangalore, Karnataka - 560040,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/h-t-m-tyres-clinic-bangalore-01432qzq_.html">
#            H T M Tyres Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           156, H K P Road, N K Complex, , Sulthangunta, Shivaji Nagar, , Bangalore, Karnataka - 560051,India
#          </p>
#         </div>
#         <div class="listing" style="padding:10px 0">
#          <div class="ad-res">
#           <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#           </script>
#           <!-- elslargevRes -->
#           <ins class="adsbygoogle" data-ad-client="ca-pub-5411435171721765" data-ad-format="horizontal" data-ad-slot="3660104734" style="display:block">
#           </ins>
#           <script>
#            (adsbygoogle = window.adsbygoogle || []).push({});
#           </script>
#          </div>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/vijaya-clinic-bangalore-z1t@2_0jb.html">
#            Vijaya Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No 83/5, Basement Arya Sevashrama Shopping Complex 1 N Bloc, Rajajinagar, , Bangalore, Karnataka - 560010,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/jeeva-veterinary-hospital-247-bangalore-kk5e68k12.html">
#            Jeeva Veterinary Hospital 24/7
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No 52/A, 9th Cross, 1st Phase, J P Nagar, , Bangalore, Karnataka - 560078,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/sri-veterinary-clinic-bangalore-iwe@lzxae.html">
#            Sri Veterinary Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No. 582/1, 7th Main, Vinayaka Layout, Nagarbhavi, , Bangalore, Karnataka - 560072,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/bangalore-pet-hospital-bangalore-0de@xo6h5.html">
#            Bangalore Pet Hospital
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.5, Varthur, Airport Main Road, Thubarahalli, Whitefield, , Bangalore, Karnataka - 560066,India
#          </p>
#         </div>
#         <div class="listing" style="padding:10px 0">
#          <div class="ad-res">
#           <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#           </script>
#           <!-- elslargevRes -->
#           <ins class="adsbygoogle" data-ad-client="ca-pub-5411435171721765" data-ad-format="horizontal" data-ad-slot="3660104734" style="display:block">
#           </ins>
#           <script>
#            (adsbygoogle = window.adsbygoogle || []).push({});
#           </script>
#          </div>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/western-speciality-pet-care-bangalore-jw_ex8k4u.html">
#            Western Speciality Pet Care
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No 21, Nagappa Street, Palace Guttahalli, , Bangalore, Karnataka - 560003,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/precise-pet-clinic-bangalore-84dex94ko.html">
#            Precise Pet Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.485 &amp; 486, 8th Cross, Jeevan Bheema Nagar Main Road, Hal 3rd Stage, Jeevan Bima Nagar, , Bangalore, Karnataka - 560075,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/samruddi-services-bangalore-6h5fxr4lr.html">
#            Samruddi Services
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.67, 1st Main Road, Annapurneshwari L/O, Handrihalli Road., Peenya 2nd Stage, , Bangalore, Karnataka - 560058,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/paws-nation-bangalore-b3z@x046_.html">
#            Paws Nation
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.13/8, 14th A Main, Bannerghatta Main Road, Btm Layout 2nd Stage, , Bangalore, Karnataka - 560076,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/sharadha-pet-clinic-bangalore-bvef6r4y1.html">
#            Sharadha Pet Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.26/3, Ganapathi Temple Street, Konappanna Aghara, , Bangalore, Karnataka - 560100,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/prajna-veterinary-clinic-bangalore-933@lrvmd.html">
#            Prajna Veterinary Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.506, 5th Main Road, 4th Cross, 2nd Block, Banashankari 3rd Stage, , Bangalore, Karnataka - 560085,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/blue-cross-veterinary-centre-bangalore-esa3k9hye.html">
#            Blue Cross Veterinary Centre
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           9, Shankarnagar Main Road, Mahalakshmipuram Layout, , Bangalore, Karnataka - 560086,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/pets-n-birds-bangalore-4xu@lr4_n.html">
#            Pets N Birds
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           New No 704, 5th Stage, 60 Feet Road, B.E.M.L. Layout, Rajarajeshwari Nagar, , Bangalore, Karnataka - 560098,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/subbus-kennel-bangalore-z2cfk0gu8.html">
#            Subbu's Kennel
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No 32, 8th Main, 15th, 1st Cross, Muthyala Nagar, , Bangalore, Karnataka - 560054,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/international-aquarium-bangalore-93se604_r.html">
#            International Aquarium
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           No.1/2, Maruthi Nagar, Skyland Road, Chandra Layout, Nagarbhavi, , Bangalore, Karnataka - 560072,India
#          </p>
#         </div>
#        </div>
#        <div class="col-lg-12 col-md-12 col-sm-12" id="loadmsg">
#        </div>
#        <div class="pagination" id="pagination">
#         <a class="btn bt-style1 mauto" href="javascript:void(0);" id="loadmore" onclick="javascript:showMoreRecord('1','hospital','pet-clinics','karnataka','bangalore','setrecord')">
#          <i class="fa fa-plus-circle">
#          </i>
#          Load More Records
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-4 col-md-4 col-sm-12">
#       <div>
#        <div class="title">
#         <h3>
#          <i class="fa fa-bullhorn">
#          </i>
#          Advertisement
#         </h3>
#        </div>
#        <div class="post">
#         <div class="ad-336">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <!-- elslargev -->
#          <ins class="adsbygoogle" data-ad-client="ca-pub-5411435171721765" data-ad-slot="9829453537" style="display:inline-block;width:300px;height:250px">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div class="title m1">
#         <h3>
#          <i class="fa fa-list-alt">
#          </i>
#          Hospital by Categoty
#         </h3>
#        </div>
#        <ul class="list-group">
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/anesthesiology-hospital">
#           Anesthesiology Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/ayurvedic-hospital">
#           Ayurvedic Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/cancer-hospital">
#           Cancer Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/cardiology-hospital">
#           Cardiology Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/children-hospital">
#           Children Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/cosmetic-and-plastic-surgery-hospital">
#           Cosmetic &amp; Plastic Surgery Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/dental-hospital">
#           Dental Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/dermatology-hospital">
#           Dermatology Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/ent-hospital">
#           ENT Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/gastroenterologist-hospital">
#           Gastroenterologist Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/general-hospital">
#           General Hospital
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div>
#        <script id="mNCC" language="javascript">
#         medianet_width = "336"; medianet_height = "280"; medianet_crid = "537462671"; medianet_versionId = "3111299";
#        </script>
#        <script src="//contextual.media.net/nmedianet.js?cid=8CU5P8N3J">
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer-bottom">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-6 col-md-6 col-sm-12">
#       <div class="f-copyright">
#        <p>
#         Copyright © 2023 healthFROG All rights reserved.
#        </p>
#       </div>
#      </div>
#      <div class="col-lg-6 col-md-6 col-sm-12">
#       <div class="social">
#        <p>
#         Share this Page on
#         <!-- Facebook -->
#         <a href="javascript:void(0);" onclick="window.open('http://www.facebook.com/sharer.php?u=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore');">
#          <img alt="Facebook" src="https://www.healthfrog.in/images/share/facebook.png"/>
#         </a>
#         <!-- Twitter -->
#         <a href="javascript:void(0);" onclick="window.open('http://twitter.com/share?url=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore&amp;text=healthFROG&amp;hashtags=healthFROG');">
#          <img alt="Twitter" src="https://www.healthfrog.in/images/share/twitter.png"/>
#         </a>
#         <!-- Google+ -->
#         <a href="javascript:void(0);" onclick="window.open('https://plus.google.com/share?url=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore');">
#          <img alt="Google" src="https://www.healthfrog.in/images/share/google.png"/>
#         </a>
#         <!-- Digg -->
#         <a href="javascript:void(0);" onclick="window.open('http://www.digg.com/submit?url=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore');">
#          <img alt="Digg" src="https://www.healthfrog.in/images/share/diggit.png"/>
#         </a>
#         <!-- Reddit -->
#         <a href="javascript:void(0);" onclick="window.open('http://reddit.com/submit?url=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore&amp;title=healthFROG');">
#          <img alt="Reddit" src="https://www.healthfrog.in/images/share/reddit.png"/>
#         </a>
#         <!-- LinkedIn -->
#         <a href="javascript:void(0);" onclick="window.open('http://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore');">
#          <img alt="LinkedIn" src="https://www.healthfrog.in/images/share/linkedin.png"/>
#         </a>
#         <!-- Pinterest -->
#         <a href="javascript:void((function()%7Bvar%20e=document.createElement('script');e.setAttribute('type','text/javascript');e.setAttribute('charset','UTF-8');e.setAttribute('src','http://assets.pinterest.com/js/pinmarklet.js?r='+Math.random()*99999999);document.body.appendChild(e)%7D)());">
#          <img alt="Pinterest" src="https://www.healthfrog.in/images/share/pinterest.png"/>
#         </a>
#         <!-- StumbleUpon-->
#         <a href="javascript:void(0);" onclick="window.open('http://www.stumbleupon.com/submit?url=https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore&amp;title=healthFROG');">
#          <img alt="StumbleUpon" src="https://www.healthfrog.in/images/share/stumbleupon.png"/>
#         </a>
#         <!-- Email -->
#         <a href="javascript:void(0);" onclick="window.location='mailto:?Subject=healthFROG&amp;Body=healthFROG https://www.healthfrog.in/hospital/pet-clinics/karnataka/bangalore'">
#          <img alt="Email" src="https://www.healthfrog.in/images/share/email.png"/>
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js">
#   </script>
#   <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js">
#   </script>
#   <!--[if lt IE 9]> <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script> <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script><![endif]-->
#   <script src="https://www.healthfrog.in/js/bootstrap-typeahead.js">
#   </script>
#   <script type="text/javascript">
#    jQuery.noConflict();	(function($) {
# $(document).ready(function(){	$('#searchText').typeahead({	source: function (query, process) {	$('#searchText').addClass("lodn");	$.ajax({	url: 'https://www.healthfrog.in/search',	type: 'GET',	dataType: 'JSON',	data: 'q=' + query,	success: function(data) {	$('#searchText').removeClass("lodn");	process(data);	}	});	},	updater : function(item){	var nm=item.split(',',1);	$('#searchVal').val(item);	var nnm=nm[0];	nnm = nnm.replace(' <span class="searchAJ-id">','');	this.$element[0].value = nnm;	this.$element[0].form.submit();	return nnm;	} });
# });
# })(jQuery);
# function changeUrl(action,value)
# {	if(action=="cat")	{	location.href="https://www.healthfrog.in/"+value;	}	else if(action=="type")	{	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+value;	}	else if(action=="state")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+value;	}	else if(action=="city")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	var state = document.getElementById("statelist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+state+'/'+value;	}
# }
# function showMoreRecord(page,mcatid,keyword,state,city,divId)
# {	var seurl = "page="+page+"&mcatid="+mcatid+"&keyword="+keyword+"&state="+state+"&city="+city;	var xmlhttp;	if (window.XMLHttpRequest)	{	xmlhttp=new XMLHttpRequest();	}	else	{	xmlhttp=new ActiveXObject("Microsoft.XMLHTTP");	};	xmlhttp.onreadystatechange=function()	{	if (xmlhttp.readyState==4 && xmlhttp.status==200)	{	page = +page + 1;	if(xmlhttp.responseText.trim()=="")	{	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'none';	}	else	{	document.getElementById(divId).innerHTML=document.getElementById(divId).innerHTML + xmlhttp.responseText;	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'block';	}	document.getElementById("loadmore").setAttribute("onClick","javascript:showMoreRecord("+page+",'"+mcatid+"','"+keyword+"','"+state+"','"+city+"','"+divId+"');");	}	else	{	document.getElementById('loadmsg').style.display = 'block';	document.getElementById('pagination').style.display = 'none';	};	};	xmlhttp.open("POST","https://www.healthfrog.in/importlisting.html",true);	xmlhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");	xmlhttp.send(seurl);
# }
#   </script>
#   <script language="javascript" type="application/javascript">
#    jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/state.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+19,	success: function(data) {	$('#statelist').append(data);	}, error: function(ajaxobj){ $('#statelist').append(ajaxobj.responseText); }	});	});	})(jQuery);
#   </script>
#   <script language="javascript" type="application/javascript">
#    jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/city.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+19+'&ctid='+324,	success: function(data) {	$('#citylist').append(data);	}, error: function(ajaxobj){ $('#citylist').append(ajaxobj.responseText); }	});	});	})(jQuery);
#   </script>
#  </body>
# </html>

# %%
pet_clinics = soup.find_all('div' , class_ = 'listing')

for clinic in pet_clinics:
    #pet_clinic_body = clinic.find('h3')
    #if pet_clinic_body:
    #    pet_clinic_name = pet_clinic_body.a.text
    #else:
    #    pass

    pet_clinic_address = clinic.find('p')
    if pet_clinic_address:
       pet_clinic_address = pet_clinic_address.text
    else:
        pass
        
    #print(pet_clinic_name)
    print(pet_clinic_address)
# Out:
# Tyre Care Centre +tyre Clinic
# Om Shiva's Tyre Clinic
# H T M Tyres Clinic
# H T M Tyres Clinic
# Vijaya Clinic
# Jeeva Veterinary Hospital 24/7
# Sri Veterinary Clinic
# Bangalore Pet Hospital
# Bangalore Pet Hospital
# Western Speciality Pet Care
# Precise Pet Clinic
# Samruddi Services
# Paws Nation
# Sharadha Pet Clinic
# Prajna Veterinary Clinic
# Blue Cross Veterinary Centre
# V Care Pet Polyclinic
# Mysore Kennel Club
# Anu Pet Clinic
# Indian Veterinary Research Institute
# Glenands Products
# Zooland Aquarium
# Alpha Kennels
# D Veterinary Clinic
# V Care Pet Policlinic
# Dee JAY Kennels
# Shevar Spa & Grooming Saloon For Dogs, CATS & Rabits - Pets
# Agrani Kennels
# Paws N Claws Pet Care
# Birdie Bird
# Cauvery Fish Aquarium
# Dr. Mohan Kumar
# Sai Pet Clinic And Shoppe
# Petbonding
# Nandi Veterinary Clinic
# Biogen Laboratory
# Pet Post
# Surya Pet Clinic
# Revathi Gotety
# Shekar Veterinary Clinic
# Pioneer Pet Clinic And Pet Shop
# A1 Faithful Pet Kennel
# Arokhya Dass A
# Wet Pets
# Digitronics
# Indus Pet World
# Herriots Poly Clinic & Pet Shop
# Karthic Aquarium
# New Look Aquarium
# Pets N Birds
# Subbu's Kennel
# International Aquarium
