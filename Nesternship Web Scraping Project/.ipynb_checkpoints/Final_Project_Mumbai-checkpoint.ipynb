# %%
from bs4 import BeautifulSoup
import lxml
import requests
import pandas as pd

# %%
html_text = requests.get('https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai').text

print(html_text)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>List of Pet Clinics in Mumbai - healthFROG </title><link rel="SHORTCUT ICON" href="https://www.healthfrog.in/images/favicon.png"/><meta name="viewport" content="width=device-width, initial-scale=1" /><link href="https://www.healthfrog.in/theme/bootstrap/bootstrap.min.css" rel="stylesheet" /><link href="https://www.healthfrog.in/theme/fa/css/font-awesome.min.css" rel="stylesheet" /><link href="https://www.healthfrog.in/theme/style.css" rel="stylesheet" /><!-- Google tag (gtag.js) --><script async src="https://www.googletagmanager.com/gtag/js?id=G-K2Z8CKG6EX"></script><script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-K2Z8CKG6EX');</script></head><body> <div id="header"> <div class="container"> <div class="row"> <div class="col-lg-3 col-md-3 col-sm-12"> <div class="logo"> <a href="https://www.healthfrog.in/">healthFROG</a> </div> </div> <div class="col-lg-6 col-md-6 col-sm-12"> <div class="hc-wrap"> <form action="https://www.healthfrog.in/searchdirectory" name="search" id="search" method="post"> <div class="form-group"> <div class="input-group"> <input class="form-control" name="search" type="text" id="searchText" autocomplete="off" placeholder="Search..."/> <input id="searchVal" name="searchval" type="hidden"/> <span class="input-group-btn"> <button class="btn btn-default" accesskey="13" type="submit"><i class="fa fa-search"></i></button> </span> </div> </div> </form> </div> </div> <div class="col-lg-3 col-md-3 col-sm-12"> <div class="hc-wrap"> <a href="https://www.healthfrog.in/add-listing.html" class="btn bt-style3 dis-bl"><i class="fa fa-plus-circle"></i>Add Your Hospital</a> </div> </div> </div> </div></div><div id="navigation"> <div class="container"> <div class="row"> <div class="col-lg-12 col-md-12 col-sm-12"> <nav class="navbar navbar-default"> <div class="container-fluid"> <div class="navbar-header"> <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1"> <span class="sr-only"><i class="fa fa-home"></i></span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span> </button> </div> <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1"> <ul class="nav navbar-nav"> <li><a href="https://www.healthfrog.in/hospital">Hospital</a></li> <li><a href="https://www.healthfrog.in/chemists">Chemists</a></li> <li><a href="https://www.healthfrog.in/doctor">Doctor</a></li> <li><a href="https://www.healthfrog.in/laboratory">Laboratory</a></li> <li><a href="https://www.healthfrog.in/health-and-fitness">Health & Fitness</a></li> </ul><ul class="nav navbar-nav navbar-right"><li><a href="javascript:void(0)">About Us</a></li><li><a href="https://www.healthfrog.in/contact-us.html">Contact Us</a></li> <li><a href="https://www.healthfrog.in/policy.html">Policy</a></li> <li><a href="https://www.healthfrog.in/signup.html">Signup</a></li><li><a href="https://www.healthfrog.in/login.html">Login</a></li> </ul> </div> </div> </nav> </div> </div> </div></div><div id="sel-nav"> <div class="container"> <div class="row"> <div class="col-lg-3 col-md-3 col-sm-6"> <div class="form-group"> <form id="catform" action=""> <select class="form-control" id="catlist" onchange="changeUrl('cat',this.options[this.selectedIndex].value)"> <option value="">Select Category</option> <option selected="selected" value="hospital"> Hospital</option> <option value="chemists"> Chemists</option> <option value="doctor"> Doctor</option> <option value="laboratory"> Laboratory</option> <option value="health-and-fitness"> Health & Fitness</option> </select> </form> </div> </div> <div class="col-lg-3 col-md-3 col-sm-6"> <div class="form-group"> <form id="typeform" action="" > <select class="form-control" id="typelist" onchange="changeUrl('type',this.options[this.selectedIndex].value)"> <option value="list">All List</ ...
# $(document).ready(function(){	$('#searchText').typeahead({	source: function (query, process) {	$('#searchText').addClass("lodn");	$.ajax({	url: 'https://www.healthfrog.in/search',	type: 'GET',	dataType: 'JSON',	data: 'q=' + query,	success: function(data) {	$('#searchText').removeClass("lodn");	process(data);	}	});	},	updater : function(item){	var nm=item.split(',',1);	$('#searchVal').val(item);	var nnm=nm[0];	nnm = nnm.replace(' <span class="searchAJ-id">','');	this.$element[0].value = nnm;	this.$element[0].form.submit();	return nnm;	} });
# });
# })(jQuery);
# function changeUrl(action,value)
# {	if(action=="cat")	{	location.href="https://www.healthfrog.in/"+value;	}	else if(action=="type")	{	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+value;	}	else if(action=="state")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+value;	}	else if(action=="city")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	var state = document.getElementById("statelist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+state+'/'+value;	}
# }
# function showMoreRecord(page,mcatid,keyword,state,city,divId)
# {	var seurl = "page="+page+"&mcatid="+mcatid+"&keyword="+keyword+"&state="+state+"&city="+city;	var xmlhttp;	if (window.XMLHttpRequest)	{	xmlhttp=new XMLHttpRequest();	}	else	{	xmlhttp=new ActiveXObject("Microsoft.XMLHTTP");	};	xmlhttp.onreadystatechange=function()	{	if (xmlhttp.readyState==4 && xmlhttp.status==200)	{	page = +page + 1;	if(xmlhttp.responseText.trim()=="")	{	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'none';	}	else	{	document.getElementById(divId).innerHTML=document.getElementById(divId).innerHTML + xmlhttp.responseText;	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'block';	}	document.getElementById("loadmore").setAttribute("onClick","javascript:showMoreRecord("+page+",'"+mcatid+"','"+keyword+"','"+state+"','"+city+"','"+divId+"');");	}	else	{	document.getElementById('loadmsg').style.display = 'block';	document.getElementById('pagination').style.display = 'none';	};	};	xmlhttp.open("POST","https://www.healthfrog.in/importlisting.html",true);	xmlhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");	xmlhttp.send(seurl);
# }</script><script language="javascript" type="application/javascript">jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/state.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+6,	success: function(data) {	$('#statelist').append(data);	}, error: function(ajaxobj){ $('#statelist').append(ajaxobj.responseText); }	});	});	})(jQuery);</script><script language="javascript" type="application/javascript">jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/city.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+6+'&ctid='+1508,	success: function(data) {	$('#citylist').append(data);	}, error: function(ajaxobj){ $('#citylist').append(ajaxobj.responseText); }	});	});	})(jQuery);</script> </body></html>

# %%
soup = BeautifulSoup(html_text, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Pet Clinics in Mumbai - healthFROG
#   </title>
#   <link href="https://www.healthfrog.in/images/favicon.png" rel="SHORTCUT ICON"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.healthfrog.in/theme/bootstrap/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://www.healthfrog.in/theme/fa/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="https://www.healthfrog.in/theme/style.css" rel="stylesheet"/>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-K2Z8CKG6EX">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-K2Z8CKG6EX');
#   </script>
#  </head>
#  <body>
#   <div id="header">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-12">
#       <div class="logo">
#        <a href="https://www.healthfrog.in/">
#         healthFROG
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-6 col-md-6 col-sm-12">
#       <div class="hc-wrap">
#        <form action="https://www.healthfrog.in/searchdirectory" id="search" method="post" name="search">
#         <div class="form-group">
#          <div class="input-group">
#           <input autocomplete="off" class="form-control" id="searchText" name="search" placeholder="Search..." type="text"/>
#           <input id="searchVal" name="searchval" type="hidden"/>
#           <span class="input-group-btn">
#            <button accesskey="13" class="btn btn-default" type="submit">
#             <i class="fa fa-search">
#             </i>
#            </button>
#           </span>
#          </div>
#         </div>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-12">
#       <div class="hc-wrap">
#        <a class="btn bt-style3 dis-bl" href="https://www.healthfrog.in/add-listing.html">
#         <i class="fa fa-plus-circle">
#         </i>
#         Add Your Hospital
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="navigation">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-12 col-md-12 col-sm-12">
#       <nav class="navbar navbar-default">
#        <div class="container-fluid">
#         <div class="navbar-header">
#          <button class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#           <span class="sr-only">
#            <i class="fa fa-home">
#            </i>
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#          <ul class="nav navbar-nav">
#           <li>
#            <a href="https://www.healthfrog.in/hospital">
#             Hospital
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/chemists">
#             Chemists
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/doctor">
#             Doctor
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/laboratory">
#             Laboratory
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/health-and-fitness">
#             Health &amp; Fitness
#            </a>
#           </li>
#          </ul>
#          <ul class="nav navbar-nav navbar-right">
#           <li>
#            <a href="javascript:void(0)">
#             About Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/contact-us.html">
#             Contact Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/policy.html">
#             Policy
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/signup.html">
#             Signup
#            </a>
#           </li>
#           <li>
#            <a href="https://www.healthfrog.in/login.html">
#             Login
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="sel-nav">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="catform">
#         <select class="form-control" id="catlist" onchange="changeUrl('cat',this.options[this.selectedIndex].value)">
#          <option value="">
#           Select Category
#          </option>
#          <option selected="selected" value="hospital">
#           Hospital
#          </option>
#          <option value="chemists">
#           Chemists
#          </option>
#          <option value="doctor">
#           Doctor
#          </option>
#          <option value="laboratory">
#           Laboratory
#          </option>
#          <option value="health-and-fitness">
#           Health &amp; Fitness
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="typeform">
#         <select class="form-control" id="typelist" onchange="changeUrl('type',this.options[this.selectedIndex].value)">
#          <option value="list">
#           All List
#          </option>
#          <option value="anesthesiology-hospital">
#           Anesthesiology Hospital
#          </option>
#          <option value="ayurvedic-hospital">
#           Ayurvedic Hospital
#          </option>
#          <option value="cancer-hospital">
#           Cancer Hospital
#          </option>
#          <option value="cardiology-hospital">
#           Cardiology Hospital
#          </option>
#          <option value="children-hospital">
#           Children Hospital
#          </option>
#          <option value="cosmetic-and-plastic-surgery-hospital">
#           Cosmetic &amp; Plastic Surgery Hospital
#          </option>
#          <option value="dental-hospital">
#           Dental Hospital
#          </option>
#          <option value="dermatology-hospital">
#           Dermatology Hospital
#          </option>
#          <option value="ent-hospital">
#           ENT Hospital
#          </option>
#          <option value="gastroenterologist-hospital">
#           Gastroenterologist Hospital
#          </option>
#          <option value="general-hospital">
#           General Hospital
#          </option>
#          <option value="gynecology-hospital">
#           Gynecology Hospital
#          </option>
#          <option value="homeopathy-hospital">
#           Homeopathy Hospital
#          </option>
#          <option value="neurology-hospital">
#           Neurology Hospital
#          </option>
#          <option value="oncology-hospital">
#           Oncology Hospital
#          </option>
#          <option value="orthopaedic-hospital">
#           Orthopaedic Hospital
#          </option>
#          <option value="private-hospital">
#           Private Hospital
#          </option>
#          <option value="psychiatric-hospital">
#           Psychiatric Hospital
#          </option>
#          <option value="radiology-hospital">
#           Radiology Hospital
#          </option>
#          <option value="diabetes-hospital">
#           Diabetes Hospital
#          </option>
#          <option value="emergency-hospital">
#           Emergency Hospital
#          </option>
#          <option value="maternity-hospital">
#           Maternity Hospital
#          </option>
#          <option value="urology-hospital">
#           Urology Hospital
#          </option>
#          <option value="nephrology-hospital">
#           Nephrology Hospital
#          </option>
#          <option value="opthalmology-hospital">
#           Opthalmology Hospital
#          </option>
#          <option value="eye-hospital">
#           Eye Hospital
#          </option>
#          <option value="rheumatology-hospital">
#           Rheumatology Hospital
#          </option>
#          <option value="hematology-hospital">
#           Hematology Hospital
#          </option>
#          <option value="immunology-hospital">
#           Immunology Hospital
#          </option>
#          <option value="mental-hospital">
#           Mental Hospital
#          </option>
#          <option value="public-hospital">
#           Public Hospital
#          </option>
#          <option value="government-hospital">
#           Government Hospital
#          </option>
#          <option value="veterinary-hospital">
#           Veterinary Hospital
#          </option>
#          <option value="multispeciality-hospital">
#           Multispeciality Hospital
#          </option>
#          <option value="cardiac-hospital">
#           Cardiac Hospital
#          </option>
#          <option value="charitable-hospital">
#           Charitable Hospital
#          </option>
#          <option value="esis-hospital">
#           Esis Hospital
#          </option>
#          <option selected="selected" value="pet-clinics">
#           Pet Clinics
#          </option>
#          <option value="public-veterinary-hospital">
#           Public Veterinary Hospital
#          </option>
#          <option value="orthodontic-hospitals">
#           Orthodontic Hospitals
#          </option>
#          <option value="dental-implants-center">
#           Dental Implants Center
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="stateform">
#         <select class="form-control" id="statelist" onchange="changeUrl('state',this.options[this.selectedIndex].value)">
#          <option value="">
#           Select State
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <div class="form-group">
#        <form action="" id="cityform">
#         <select class="form-control" id="citylist" onchange="changeUrl('city',this.options[this.selectedIndex].value)">
#          <option value="">
#           Select City
#          </option>
#         </select>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="body">
#    <div class="container">
#     <div class="row">
#      <div align="center" class="m1">
#       <script id="mNCC" language="javascript">
#        medianet_width = "970"; medianet_height = "90"; medianet_crid = "834543454"; medianet_versionId = "3111299";
#       </script>
#       <script src="//contextual.media.net/nmedianet.js?cid=8CU5P8N3J">
#       </script>
#      </div>
#      <div class="col-lg-8 col-md-8 col-sm-12">
#       <div class="lising-wrap">
#        <div class="title">
#         <h1>
#          <i class="fa fa-th-list">
#          </i>
#          List of Pet Clinics in Mumbai
#         </h1>
#        </div>
#        <div class="post p0" id="setrecord">
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/dr-shailesh-k-khade-mumbai-k02cl8yjx.html">
#            Dr Shailesh K Khade
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No.42, Vasant Smruti, Thakur Complex, 90 Ft Road, Thakur Complex-Kandivali East, , Mumbai, Maharashtra - 400101,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/metrovet-pet-clinic-and-pet-shop-mumbai-g80fkjcfi.html">
#            Metrovet Pet Clinic &amp; Pet Shop
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 29, Bhoomi Park Phase 1, Jankalyan Nagar, Malad West, , Mumbai, Maharashtra - 400095,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/vet-4-ur-pet-mumbai-y1v3xx2r7.html">
#            Vet 4 Ur Pet
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           10, Sterling Chs, Sundarvan, Off Lokhandwala Road, Andheri West, , Mumbai, Maharashtra - 400053,India
#          </p>
#         </div>
#         <div class="listing" style="padding:10px 0">
#          <div class="ad-res">
#           <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#           </script>
#           <!-- elslargevRes -->
#           <ins class="adsbygoogle" data-ad-client="ca-pub-5411435171721765" data-ad-format="horizontal" data-ad-slot="3660104734" style="display:block">
#           </ins>
#           <script>
#            (adsbygoogle = window.adsbygoogle || []).push({});
#           </script>
#          </div>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/chips-n-bytes-pet-shop-mumbai-j06@lxc09.html">
#            Chips N Bytes Pet Shop
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           5 A, 5 B, Vishnu Towers, P K Road, Mulund West, , Mumbai, Maharashtra - 400080,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/pet-animal-clinic-mumbai-8myflxcr_.html">
#            Pet Animal Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 7, Rameshwaram Building, Chatrapati Shivaji Marg, X Road No 3, Dahisar, , Mumbai, Maharashtra - 400068,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/metrovet-pet-clinic-mumbai-59hekxdqa.html">
#            Metrovet Pet Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 13, Bhoomi Park 2, E Wing, Malad West, , Mumbai, Maharashtra - 400064,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/dr-komals-pet-clinic-mumbai-qud366tqd.html">
#            Dr Komals Pet Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Plot No 3, Varad Bunglow, New India Society, Juhu, , Mumbai, Maharashtra - 400049,India
#          </p>
#         </div>
#         <div class="listing" style="padding:10px 0">
#          <div class="ad-res">
#           <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#           </script>
#           <!-- elslargevRes -->
#           <ins class="adsbygoogle" data-ad-client="ca-pub-5411435171721765" data-ad-format="horizontal" data-ad-slot="3660104734" style="display:block">
#           </ins>
#           <script>
#            (adsbygoogle = window.adsbygoogle || []).push({});
#           </script>
#          </div>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/paws-n-claws-pet-care-center-mumbai-x36@6x2uh.html">
#            Paws N Claws Pet Care Center
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Chandrika Niwas, Shop No 3, Pipe Line Bus Stop, Lbs Road, Ghatkopar West, , Mumbai, Maharashtra - 400086,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/acumed-veterinary-specialty-mumbai-04zf6kcqy.html">
#            Acumed Veterinary Specialty
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 19 &amp; 20, Swapnapurti CHS Ltd, Jivla-Pada, Thakur Village-Kandivali East, , Mumbai, Maharashtra - 400101,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/top-dog-pets-clinic-mumbai-3t1@k6t__.html">
#            Top Dog Pets Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 2, Vishal Nagar Society, J P Road, Andheri West, , Mumbai, Maharashtra - 400061,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/pluto-pet-clinic-mumbai-vcuf6keaa.html">
#            Pluto Pet Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 4, Parul Apartment, Andheri West, , Mumbai, Maharashtra - 400053,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/karunya-pets-clinic-and-doggy-articles-mumbai-lyzfk6@sh.html">
#            Karunya Pets Clinic And Doggy Articles
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop A 1 Ratan Heights Building, Dr Db Marg, Mumbai Central, , Mumbai, Maharashtra - 400008,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/narsinghani-homoeopathic-and-nutrition-clinic-mumbai-lbh3k6@c3.html">
#            Narsinghani Homoeopathic And Nutrition Clinic
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           12 Gulmohar Road, , Mumbai, Maharashtra - 400049,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/dr-sushma-jadhav-mumbai-cpj3lledg.html">
#            Dr Sushma Jadhav
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           2/36 Gulmohar Building, Bhavani Shankar Road, Dadar West, , Mumbai, Maharashtra - 400028,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/delkarsh-chemist-mumbai-9m8@kk@ci.html">
#            Delkarsh Chemist
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           S.S.Rao Road, Parel, , Mumbai, Maharashtra - 400012,India
#          </p>
#         </div>
#         <div class="listing">
#          <h3>
#           <a href="https://www.healthfrog.in/hospital/pet-clinic-and-pet-accessories-shop-mumbai-s@03xx@2l.html">
#            Pet Clinic &amp; Pet Accessories Shop
#           </a>
#          </h3>
#          <p>
#           <i class="fa fa-map-marker">
#           </i>
#           Shop No 44, Yash Paradise Sector 8 A Navi, Mumbai Central, , Mumbai, Maharashtra - 400008,India
#          </p>
#         </div>
#        </div>
#        <div class="col-lg-12 col-md-12 col-sm-12" id="loadmsg">
#        </div>
#        <div class="pagination" id="pagination">
#         <a class="btn bt-style1 mauto" href="javascript:void(0);" id="loadmore" onclick="javascript:showMoreRecord('1','hospital','pet-clinics','maharashtra','mumbai','setrecord')">
#          <i class="fa fa-plus-circle">
#          </i>
#          Load More Records
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-4 col-md-4 col-sm-12">
#       <div>
#        <div class="title">
#         <h3>
#          <i class="fa fa-bullhorn">
#          </i>
#          Advertisement
#         </h3>
#        </div>
#        <div class="post">
#         <div class="ad-336">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <!-- elslargev -->
#          <ins class="adsbygoogle" data-ad-client="ca-pub-5411435171721765" data-ad-slot="9829453537" style="display:inline-block;width:300px;height:250px">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div class="title m1">
#         <h3>
#          <i class="fa fa-list-alt">
#          </i>
#          Hospital by Categoty
#         </h3>
#        </div>
#        <ul class="list-group">
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/anesthesiology-hospital">
#           Anesthesiology Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/ayurvedic-hospital">
#           Ayurvedic Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/cancer-hospital">
#           Cancer Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/cardiology-hospital">
#           Cardiology Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/children-hospital">
#           Children Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/cosmetic-and-plastic-surgery-hospital">
#           Cosmetic &amp; Plastic Surgery Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/dental-hospital">
#           Dental Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/dermatology-hospital">
#           Dermatology Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/ent-hospital">
#           ENT Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/gastroenterologist-hospital">
#           Gastroenterologist Hospital
#          </a>
#         </li>
#         <li class="list-group-item">
#          <a href="https://www.healthfrog.in/hospital/general-hospital">
#           General Hospital
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div>
#        <script id="mNCC" language="javascript">
#         medianet_width = "336"; medianet_height = "280"; medianet_crid = "537462671"; medianet_versionId = "3111299";
#        </script>
#        <script src="//contextual.media.net/nmedianet.js?cid=8CU5P8N3J">
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer-bottom">
#    <div class="container">
#     <div class="row">
#      <div class="col-lg-6 col-md-6 col-sm-12">
#       <div class="f-copyright">
#        <p>
#         Copyright © 2023 healthFROG All rights reserved.
#        </p>
#       </div>
#      </div>
#      <div class="col-lg-6 col-md-6 col-sm-12">
#       <div class="social">
#        <p>
#         Share this Page on
#         <!-- Facebook -->
#         <a href="javascript:void(0);" onclick="window.open('http://www.facebook.com/sharer.php?u=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai');">
#          <img alt="Facebook" src="https://www.healthfrog.in/images/share/facebook.png"/>
#         </a>
#         <!-- Twitter -->
#         <a href="javascript:void(0);" onclick="window.open('http://twitter.com/share?url=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai&amp;text=healthFROG&amp;hashtags=healthFROG');">
#          <img alt="Twitter" src="https://www.healthfrog.in/images/share/twitter.png"/>
#         </a>
#         <!-- Google+ -->
#         <a href="javascript:void(0);" onclick="window.open('https://plus.google.com/share?url=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai');">
#          <img alt="Google" src="https://www.healthfrog.in/images/share/google.png"/>
#         </a>
#         <!-- Digg -->
#         <a href="javascript:void(0);" onclick="window.open('http://www.digg.com/submit?url=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai');">
#          <img alt="Digg" src="https://www.healthfrog.in/images/share/diggit.png"/>
#         </a>
#         <!-- Reddit -->
#         <a href="javascript:void(0);" onclick="window.open('http://reddit.com/submit?url=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai&amp;title=healthFROG');">
#          <img alt="Reddit" src="https://www.healthfrog.in/images/share/reddit.png"/>
#         </a>
#         <!-- LinkedIn -->
#         <a href="javascript:void(0);" onclick="window.open('http://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai');">
#          <img alt="LinkedIn" src="https://www.healthfrog.in/images/share/linkedin.png"/>
#         </a>
#         <!-- Pinterest -->
#         <a href="javascript:void((function()%7Bvar%20e=document.createElement('script');e.setAttribute('type','text/javascript');e.setAttribute('charset','UTF-8');e.setAttribute('src','http://assets.pinterest.com/js/pinmarklet.js?r='+Math.random()*99999999);document.body.appendChild(e)%7D)());">
#          <img alt="Pinterest" src="https://www.healthfrog.in/images/share/pinterest.png"/>
#         </a>
#         <!-- StumbleUpon-->
#         <a href="javascript:void(0);" onclick="window.open('http://www.stumbleupon.com/submit?url=https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai&amp;title=healthFROG');">
#          <img alt="StumbleUpon" src="https://www.healthfrog.in/images/share/stumbleupon.png"/>
#         </a>
#         <!-- Email -->
#         <a href="javascript:void(0);" onclick="window.location='mailto:?Subject=healthFROG&amp;Body=healthFROG https://www.healthfrog.in/hospital/pet-clinics/maharashtra/mumbai'">
#          <img alt="Email" src="https://www.healthfrog.in/images/share/email.png"/>
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js">
#   </script>
#   <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js">
#   </script>
#   <!--[if lt IE 9]> <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script> <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script><![endif]-->
#   <script src="https://www.healthfrog.in/js/bootstrap-typeahead.js">
#   </script>
#   <script type="text/javascript">
#    jQuery.noConflict();	(function($) {
# $(document).ready(function(){	$('#searchText').typeahead({	source: function (query, process) {	$('#searchText').addClass("lodn");	$.ajax({	url: 'https://www.healthfrog.in/search',	type: 'GET',	dataType: 'JSON',	data: 'q=' + query,	success: function(data) {	$('#searchText').removeClass("lodn");	process(data);	}	});	},	updater : function(item){	var nm=item.split(',',1);	$('#searchVal').val(item);	var nnm=nm[0];	nnm = nnm.replace(' <span class="searchAJ-id">','');	this.$element[0].value = nnm;	this.$element[0].form.submit();	return nnm;	} });
# });
# })(jQuery);
# function changeUrl(action,value)
# {	if(action=="cat")	{	location.href="https://www.healthfrog.in/"+value;	}	else if(action=="type")	{	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+value;	}	else if(action=="state")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+value;	}	else if(action=="city")	{	var type = document.getElementById("typelist").value;	var cat = document.getElementById("catlist").value;	var state = document.getElementById("statelist").value;	location.href="https://www.healthfrog.in/"+cat+'/'+type+'/'+state+'/'+value;	}
# }
# function showMoreRecord(page,mcatid,keyword,state,city,divId)
# {	var seurl = "page="+page+"&mcatid="+mcatid+"&keyword="+keyword+"&state="+state+"&city="+city;	var xmlhttp;	if (window.XMLHttpRequest)	{	xmlhttp=new XMLHttpRequest();	}	else	{	xmlhttp=new ActiveXObject("Microsoft.XMLHTTP");	};	xmlhttp.onreadystatechange=function()	{	if (xmlhttp.readyState==4 && xmlhttp.status==200)	{	page = +page + 1;	if(xmlhttp.responseText.trim()=="")	{	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'none';	}	else	{	document.getElementById(divId).innerHTML=document.getElementById(divId).innerHTML + xmlhttp.responseText;	document.getElementById('loadmsg').style.display = 'none';	document.getElementById('pagination').style.display = 'block';	}	document.getElementById("loadmore").setAttribute("onClick","javascript:showMoreRecord("+page+",'"+mcatid+"','"+keyword+"','"+state+"','"+city+"','"+divId+"');");	}	else	{	document.getElementById('loadmsg').style.display = 'block';	document.getElementById('pagination').style.display = 'none';	};	};	xmlhttp.open("POST","https://www.healthfrog.in/importlisting.html",true);	xmlhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");	xmlhttp.send(seurl);
# }
#   </script>
#   <script language="javascript" type="application/javascript">
#    jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/state.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+6,	success: function(data) {	$('#statelist').append(data);	}, error: function(ajaxobj){ $('#statelist').append(ajaxobj.responseText); }	});	});	})(jQuery);
#   </script>
#   <script language="javascript" type="application/javascript">
#    jQuery.noConflict();	(function($) {	$(document).ready(function(e) { $.ajax({	url: 'https://www.healthfrog.in/home/city.html',	type: 'GET',	dataType: 'JSON',	data: 'cat_id=' + 2+'&sid='+88+'&stid='+6+'&ctid='+1508,	success: function(data) {	$('#citylist').append(data);	}, error: function(ajaxobj){ $('#citylist').append(ajaxobj.responseText); }	});	});	})(jQuery);
#   </script>
#  </body>
# </html>

# %%
pet_clinics = soup.find_all('div' , class_ = 'listing')

for clinic in pet_clinics:
    pet_clinic_body = clinic.find('h3')
    if pet_clinic_body:
        pet_clinic_name = pet_clinic_body.a.text
    else:
       pass

    #pet_clinic_address = clinic.find('p')
    #if pet_clinic_address:
    #   pet_clinic_address = pet_clinic_address.text
    #else:
    #    pass
        
    print(pet_clinic_name)
    #print(pet_clinic_address)
# Out:
# Shop No.42, Vasant Smruti, Thakur Complex, 90 Ft Road, Thakur Complex-Kandivali East, , Mumbai, Maharashtra - 400101,India
# Shop No 29, Bhoomi Park Phase 1, Jankalyan Nagar, Malad West, , Mumbai, Maharashtra - 400095,India
# 10, Sterling Chs, Sundarvan, Off Lokhandwala Road, Andheri West, , Mumbai, Maharashtra - 400053,India
# None
# 5 A, 5 B, Vishnu Towers, P K Road, Mulund West, , Mumbai, Maharashtra - 400080,India
# Shop No 7, Rameshwaram Building, Chatrapati Shivaji Marg, X Road No 3, Dahisar, , Mumbai, Maharashtra - 400068,India
# Shop No 13, Bhoomi Park 2, E Wing, Malad West, , Mumbai, Maharashtra - 400064,India
# Plot No 3, Varad Bunglow, New India Society, Juhu, , Mumbai, Maharashtra - 400049,India
# None
# Chandrika Niwas, Shop No 3, Pipe Line Bus Stop, Lbs Road, Ghatkopar West, , Mumbai, Maharashtra - 400086,India
# Shop No 19 & 20, Swapnapurti CHS Ltd, Jivla-Pada, Thakur Village-Kandivali East, , Mumbai, Maharashtra - 400101,India
# Shop No 2, Vishal Nagar Society, J P Road, Andheri West, , Mumbai, Maharashtra - 400061,India
# Shop No 4, Parul Apartment, Andheri West, , Mumbai, Maharashtra - 400053,India
# Shop A 1 Ratan Heights Building, Dr Db Marg, Mumbai Central, , Mumbai, Maharashtra - 400008,India
# 12 Gulmohar Road, , Mumbai, Maharashtra - 400049,India
# 2/36 Gulmohar Building, Bhavani Shankar Road, Dadar West, , Mumbai, Maharashtra - 400028,India
# S.S.Rao Road, Parel, , Mumbai, Maharashtra - 400012,India
# Shop No 44, Yash Paradise Sector 8 A Navi, Mumbai Central, , Mumbai, Maharashtra - 400008,India
